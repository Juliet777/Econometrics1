# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline

# %%
df = pd.read_excel(r'D:\Uni\2курс(2021-2022)\Прикладная эконометрика\Econometrics1\DTP.xls')

# %%
df.to_csv (r'D:\Uni\2курс(2021-2022)\Прикладная эконометрика\Econometrics1\DTP.csv', index = None, header=True)
df = pd.read_csv(r'D:\Uni\2курс(2021-2022)\Прикладная эконометрика\Econometrics1\DTP.csv')

# %%
df.head()
# Out:
#        Country    lnCARS  DEV   lnLENTH     lnALC     lnDTP
# 0  Afghanistan  3.295837    0  4.175871 -3.506558  3.222868
# 1      Albania  4.736198    0  6.439559  1.986504  2.230014
# 2      Algeria  4.691348    0  3.865336 -0.371064  2.674149
# 3       Angola  3.695855    0  3.719702  1.717395  3.589059
# 4    Argentina  5.807662    0  4.426312  2.235376  2.501436

# %%
df.describe()
# Out:
#            lnCARS         DEV     lnLENTH       lnALC       lnDTP
# count  144.000000  144.000000  144.000000  144.000000  144.000000
# mean     4.596124    0.201389    5.654249    1.488305    2.716770
# std      1.540724    0.402438    1.455823    1.267008    0.652904
# min      0.693147    0.000000    1.557926   -3.506558    1.131402
# 25%      3.596883    0.000000    4.674932    1.127281    2.300073
# 50%      4.840172    0.000000    5.684371    1.863297    2.785011
# 75%      5.881035    0.000000    6.732724    2.322633    3.167523
# max      6.703188    1.000000    9.189879    3.135929    3.977811

# %%
df.columns
# Out:
# Index(['Country', 'lnCARS', 'DEV', 'lnLENTH', 'lnALC', 'lnDTP'], dtype='object')

# %%
y = df['lnDTP']
x = df[['lnCARS','DEV','lnLENTH','lnALC']]
x = sm.add_constant(x)

model1 = sm.OLS(y, x) 
result = model1.fit()
result.summary()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  lnDTP   R-squared:                       0.523
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     38.05
# Date:                Fri, 03 Jun 2022   Prob (F-statistic):           1.78e-21
# Time:                        18:07:33   Log-Likelihood:                -89.190
# No. Observations:                 144   AIC:                             188.4
# Df Residuals:                     139   BIC:                             203.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %%
y = df['lnDTP']
x = df[['DEV','lnALC']]
x = sm.add_constant(x)

model = sm.OLS(y, x) 
result = model.fit()
result.summary()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  lnDTP   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     52.01
# Date:                Fri, 03 Jun 2022   Prob (F-statistic):           1.21e-17
# Time:                        17:36:12   Log-Likelihood:                -102.65
# No. Observations:                 144   AIC:                             211.3
# Df Residuals:                     141   BIC:                             220.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
y = df['lnDTP']
x = df[['lnCARS','lnLENTH']]
x = sm.add_constant(x)

model2 = sm.OLS(y, x) 
result = model2.fit()
result.summary()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  lnDTP   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.404
# Method:                 Least Squares   F-statistic:                     49.56
# Date:                Fri, 03 Jun 2022   Prob (F-statistic):           5.00e-17
# Time:                        18:07:44   Log-Likelihood:                -104.10
# No. Observations:                 144   AIC:                             214.2
# Df Residuals:                     141   BIC:                             223.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# Так как теста Рамсея здесь нет, я его провела через Stata.
# Ramsey RESET test using powers of the fitted values of lnDTP
#        Ho:  model has no omitted variables
#                  F(3, 136) =      2.15
#                   Prob > F =      0.0964
# Исходя из таблицы Фишера, гипотеза об отсутствии упущенных переменных подтвердилась.

# %% [markdown]
# Answers: 2 -A, 3 - A, 4 - A, 5 - A
